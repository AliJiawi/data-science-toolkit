# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive
# !mkdir -p git_repos
# %cd git_repos
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive
# /content/drive/MyDrive/git_repos

# %%
# !git clone https://github.com/AliJiawi/data-science-toolkit.git
# Out:
# Cloning into 'data-science-toolkit'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd data-science-toolkit/
# Out:
# /content/drive/MyDrive/git_repos/data-science-toolkit

# %%
# !git config --global user.email "25071095@siswa.um.edu.my"
# !git config --global user.name "AliJiawi"

# %%
# !ls
# Out:
# README.md

# %%
# !mv "../../Colab Notebooks/Setup.ipynb" "./"

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Setup.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .
# !git commit -m "first commit"
# Out:
# [main ebd253d] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 Setup.ipynb

# %%
# !ls
# Out:
# README.md  Setup.ipynb

# %%
# !git push https://AliJiawi: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@github.com/AliJiawi/data-science-toolkit.git main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.53 KiB | 130.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/AliJiawi/data-science-toolkit.git
#    5ea468c..ebd253d  main -> main

# %%
# !git branch library/numpy

# %%
# !git branch
# Out:
#   library/numpy
# * main
